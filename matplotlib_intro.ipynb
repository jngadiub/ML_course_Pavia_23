# %% [markdown]
# <a href="https://colab.research.google.com/github/jngadiub/ML_course_Pavia_23/blob/main/matplotlib_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Matplotlib
#
# Based on [W3Schools tutorial](https://www.w3schools.com/python/matplotlib_intro.asp) and [Wuhan DL Lab](https://github.com/farakiko/wuhan_DL_labs/blob/master/general/Matplotlib_Cheatsheet.ipynb).
#
# **What is Matplotlib?**
#
# [Matplotlib](https://github.com/matplotlib/matplotlib) is a low level graph plotting library in python that serves as a visualization utility. It was created by John D. Hunter and it is open source and we can use it freely. It is mostly written in python, a few segments are written in C, Objective-C and Javascript for Platform compatibility.

# %% [markdown]
# ### Import packages and check version
#
# Most of the Matplotlib utilities lies under the `pyplot` submodule, and are usually imported under the `plt` alias as below. After the `import` command the `pyplot` package can be referred to as `plt`.

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import sys

print('Matplotlib Version: ' + mpl.__version__)
print('NumPy Version: ' + np.version.full_version)
print('Python Version: ' + sys.version)
# Out:
# Matplotlib Version: 3.2.2
# NumPy Version: 1.21.6
# Python Version: 3.8.16 (default, Dec  7 2022, 01:12:13)
# [GCC 7.5.0]

# %% [markdown]
# ### Plotting x and y points
#
# The `plot()` function of `plt` is used to draw points (markers) in a diagram. By default, the function draws a line from point to point. It takes parameters that specify points in the diagram:
#
# *   Parameter 1 is an array containing the points on the x-axis.
# *   Parameter 2 is an array containing the points on the y-axis.
#
# If we need to plot a line from (1, 3) to (8, 10), we have to pass two arrays [1, 8] and [3, 10] to the function:

# %%
xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints)

# %% [markdown]
# If you don't want to plot the line connecting the points you can use shortcut string notation parameter `'o'`, which means *rings*:

# %%
plt.plot(xpoints, ypoints, 'o')

# %% [markdown]
# You can plot as many points as you like, just make sure you have the same number of points in both axis.
#
# *Exercise: plot a graph that has more than two values in both the x and y axis.*

# %% [markdown]
# To plot multiple graphs on the same plot just call the `plot` functions consecutively:

# %%
y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1)
plt.plot(y2)

# %% [markdown]
# *Exercise: what are the default x values when not specified?*

# %% [markdown]
# ### Style
#
# Matplotlib has plenty of freedom to change the plotting style. Please refer to documentation for changing it:
#
# * styles for the markers at [link](https://matplotlib.org/stable/api/markers_api.html)
# * styles for the connecting lines at [link](https://matplotlib.org/stable/gallery/lines_bars_and_markers/linestyles.html)
# * colors examples at [link](https://matplotlib.org/stable/tutorials/colors/colors.html)
#
# You can also define the `markersize` and separately the `markeredgecolor` and the `markerfacecolor`. Other costum options include the line color and width. All options can be found in the [`pyplot` documentation](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html).
#
# *Exercise: import the XXX dataset and plot it in at least 4 different styles changing both line and markers style.*

# %% [markdown]
# ### Labels
#
# With `pyplot`, you can use the `xlabel()` and `ylabel()` functions to set a label for the x- and y-axis.

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Particle Mass")
plt.ylabel("Events")
# Out:
# Text(0, 0.5, 'Events')

# %% [markdown]
# You can use the `title()` function to set a title for the plot:

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.title("My physics analysis")
plt.xlabel("Particle Mass")
plt.ylabel("Events")
# Out:
# Text(0, 0.5, 'Events')

# %% [markdown]
# You can use the `fontdict` parameter in `xlabel()`, `ylabel()`, and `title()` to set font properties for the title and labels:

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("My physics analysis", fontdict = font1)
plt.xlabel("Particle Mass", fontdict = font2)
plt.ylabel("Events", fontdict = font2)

plt.plot(x, y)

# %% [markdown]
# You can use the `loc` parameter in `title()` to position the title:

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.title("My physics analysis", loc='left')
plt.xlabel("Particle Mass")
plt.ylabel("Events")
# Out:
# Text(0, 0.5, 'Events')

# %% [markdown]
# ### Grid
#
# With `pyplot`, you can use the `grid()` function to add grid lines to the plot:

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.title("My physics analysis")
plt.xlabel("Particle Mass")
plt.ylabel("Events")

plt.grid()

# %% [markdown]
# And you can use the `axis` parameter in the `grid()` function to specify which grid lines to display. Legal values are: `'x'`, `'y'`, and `'both'`. Default value is `'both'`.
#
# As for the main plot lines style can be specified in the same manner for the grid.
#
# *Exercise: plot only y-axis grid lines in your favourite style different from the default one.*

# %% [markdown]
# ### Multiple plots
#
# With the `subplot()` function you can draw multiple plots in one figure. The `subplot()` function takes three arguments that describes the layout of the figure. The layout is organized in rows and columns, which are represented by the first and second argument. The third argument represents the index of the current plot.

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1) #the figure has 1 row, 2 columns, and this plot is the first plot. 
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2) #the figure has 1 row, 2 columns, and this plot is the second plot
plt.plot(x,y)

# %% [markdown]
# *Exercise: make six plots in one figure arranged over two rows. Also add a title to each of the plots.*

# %% [markdown]
# ### Scatter plots
#
# With `pyplot`, you can use the `scatter()` function to draw a scatter plot. The function plots one dot for each observation. It needs two arrays of the same length, one for the values of the x-axis, and one for values on the y-axis:

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)

# %% [markdown]
# *Exercise: on top of the scatter plot data above draw another set of data in a different color.*

# %% [markdown]
# **Scatter plot style**
#
# You can set your own color for each scatter plot with the `color` or the `c` argument:

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999')

# %% [markdown]
# You can even set a specific color for each dot by using an array of colors as value for the `c` argument:

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

# %% [markdown]
# **Color Map**
#
# The **Matplotlib** module has a number of available maps of colours. A c*olormap* is like a list of colors, where each color has a value that ranges from 0 to 100. We will see an example below but you can also find [here](https://matplotlib.org/stable/tutorials/colors/colormaps.html) the full list of *colormaps*.

# %% [markdown]
# You can specify the *colormap* with the keyword argument `cmap` with the value of the *colormap*, in this case `'viridis'` which is one of the built-in colormaps available in Matplotlib.
#
# In addition you have to create an array with values (from 0 to 100), one value for each point in the scatter plot:

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

# %% [markdown]
# You can include the colormap in the drawing by including the `plt.colorbar()` statement:

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.colorbar()

# %% [markdown]
# **From colours to size maps**
#
# You can change the size of the dots with the `s` argument. Just like colors, make sure the array for sizes has the same length as the arrays for the x- and y-axis:

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes)

# %% [markdown]
# You can adjust the transparency of the dots with the `alpha` argument:

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes, alpha=0.5)

# %% [markdown]
# You can combine a *colormap* with different sizes of the dots. This is best visualized if the dots are transparent:

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

# %% [markdown]
# ### Plotting bars
#
# In `pyplot`, you can use the `bar()` function to draw bar graphs:

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# If you want the bars to be displayed horizontally instead of vertically, use the `barh()` function:

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# *Exercise: make your own bar plot changing bar color and width/height from default.*

# %% [markdown]
# ### Histograms
#
# In Matplotlib, we use the `hist()` function to create histograms. This function will use an array of numbers to create a histogram, the array is sent into the function as an argument.

# %%
x = np.random.normal(170, 10, 250)
plt.hist(x)
# Out:
# (array([10., 19., 22., 35., 46., 54., 30., 16., 11.,  7.]),
#  array([145.60964555, 150.55727623, 155.50490691, 160.45253759,
#         165.40016827, 170.34779896, 175.29542964, 180.24306032,
#         185.190691  , 190.13832168, 195.08595237]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# *Exercise: plot a Poisson distribution.*

# %% [markdown]
# ### More freedom with the `ax` object
#
# You can gain more control in plotting style when using the `axis` object returned by either a `plot` or a `subplot` function. Let's see below a few examples.

# %% [markdown]
# **Example:**
#
# with the `axis` objects returned by `subplots` you can decide freely the notation of each of the subplots rather than globally for both of them as this costumization would not be available otherwise.

# %%
x = np.linspace(0,2*np.pi,10**3)
y = np.sin(x) + np.cos(x)

fig,(ax1,ax2) = plt.subplots(1,2,figsize=(7,3),dpi=100,num=1)

# Regular notation
ax1.plot(x,1e4*y)

# Scientific notation
ax2.plot(x,1e4*y)

from matplotlib import ticker
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True) 
formatter.set_powerlimits((-1,1))

ax2.yaxis.set_major_formatter(formatter)

# %% [markdown]
# ### Legends
#
# There are a few ways to work a legend. And there is a lot more that can be found on the web. The main takeaway is to have `label=` in the respective plot:

# %%
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(7,3),dpi=100,num=1,sharey=True)

X = np.linspace(0,2*np.pi,1000)

ax1.plot(X,np.sin(X),label='One')
ax1.plot(X,np.cos(X),label='Two')
ax1.plot(X,np.sin(np.cos(X)),label='Three')
ax1.legend()

ax2.plot(X,np.sin(X),label='One')
ax2.plot(X,np.cos(X)) # NO LABEL
ax2.plot(X,np.sin(np.cos(X)),label='Three')
ax2.legend()
